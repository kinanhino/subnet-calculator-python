# %% [markdown]
# # **Python Subnet Calculator**

# %% [markdown]
# # ![IP ranges and default subnets.png](data:image/png;base64,...)![Pubconcierge-Subnet-Class.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Python Subnet Calculator**
# ---
# ### This calculator can take an IP address as input, validate its correctness, determine its class (A, B, or C), and provide CIDR notation either given by the user or inferred from the IP class.
#
# What we need:
# 1. Ask the user to input the number
#  - Only 4 octets separated by a dot
#  - 1 Octet can contain numbers from 0 to 255 only
# 2. Validation input
# 3. Calculate Subnet ( A - 255.0.0.0, B - 255.255.0.0, C - 255.255.255.0)
# 4. Get Subner from CIDR
# ---
#
# ## **IP Validation:**
#
# * Ensure the input IP is in the correct format (xxx.xxx.xxx.xxx)
# * Ensure each segment (octet) is between 0 and 255
# * Identify the IP class (A, B, C)
#
# ## **CIDR Notation:**
#
# * Ensure the input is in the correct format.
# * User can input CIDR notation if known.
# * If CIDR is not provided, it is inferred based on the IP class.
#
# ## **Inputs:**
#
# * IP Address: A valid IPv4 address.
# * CIDR Notation (optional): If not provided, the tool infers it from the IP class.
# * Partitioning Preference: Whether the user wants to partition based on the number of hosts or subnets.
# * Number: Depending on the above choice, the number of hosts or subnets.
#
# ## **Outputs:**
#
# * Subnet Mask: Displayed in decimal format.
# * CIDR Notation: (/24)
# * Number of Hosts: Total possible hosts in the subnet.
# * Number of Subnets: Total possible subnets.
# * Network and Broadcast Addresses: For the first two and the last two subnets.
#
# ## **Usage:**
#
# Provide the required inputs and get the relevant subnetting information in return.

# %%
# Validates an IP address.
# Args:
# - IP (str): The IP address to be validated.
# Returns:
# - Boolean: A Boolean Variable indicating if the IP is valid.

def ip_validate(ip):
  ip_list = ip.split('.') #Splits the IP into its 4 octets
  if len(ip_list) != 4: #Checks if there are exactly 4 octets
    return False
  for value in ip_list:
    if not value.isdigit():  ##Ensures each octet is a number
      return False
    value = int(value)
    if not 0 <= value <= 255: #Ensures each octet is a number between 0 and 255
      return False
  return True

# %%
# Validates a Given CIDR.
# Args:
# - cidr: The CIDR to be validated
# - IP (str): The IP address that the cidr must comply to.
# Returns:
# - Boolean: A Boolean Variable indicating if the CIDR is valid.

def cidr_validate(cidr, ip):
  if cidr.isdigit():
    cidr = int(cidr)
    if class_bit(ip) <= cidr <= 32:
      return True
    else:
      print("Invalid CIDR input.")
      return False
  else:
    print("Invalid CIDR input.")
    return False


# Determine the class of an IP.
# Args:
# - IP (str): The IP address that we want to know it's class.
# Returns:
# - String: A String Variable indicating the Class the IP belongs to.

def determine_class(ip):
  ip_list = ip.split('.')
  octet = ip_list[0]
  octet = int(octet)
  if 0 <= octet <= 127:
    return 'Class A'
  elif 128 <= octet <= 191:
    return 'Class B'
  elif 192 <= octet <= 223:
    return 'Class C'
  elif 224 <= octet <= 239:
    return 'Class D'
  elif 240 <= octet <= 255:
    return 'Class E'
  else:
    return 'Something is wrong'


# Determine the fixed bits number of an IP.
# Args:
# - IP (str): The IP address that we want to know it's fixed number of bits.
# Returns:
# - String: A String Variable indicating the Class the IP belongs to.

def class_bit(ip):
  det = determine_class(ip)
  if det == 'Class A':
    return 8
  elif det == 'Class B':
    return 16
  elif det == 'Class C':
    return 24
  else:
    return 'Not applicable'

# %%
# Get the Hosts number of a network given the IP and the CIDR
# Args:
# - IP: The IP address to be checked.
# - cidr: The CIDR we want to check against
# Returns:
# - Integer: An Integer Variable containing the number of available Hosts.
def get_hosts_number(ip, cidr):
    ip_class = determine_class(ip)
    hosts = 0
    cidr = int(cidr)
    if ip_class == 'Class A' or ip_class == 'Class B' or ip_class == 'Class C':
        hosts = 2 ** (32 - cidr) - 2
        return hosts
    
    
# Get the Subnets number of a network given the IP and the CIDR
# Args:
# - IP: The IP address to be checked.
# - cidr: The CIDR we want to check against
# Returns:
# - Integer: An Integer Variable containing the number of the Subnets.
def get_subnets_number(ip, cidr):
    ip_class = class_bit(ip)
    if ip_class != 'Not applicable':
      subnets = 2 ** (int(cidr) - int(ip_class))
    return subnets


# Calculates the subnet mask for a given CIDR (including Network Class bit and the Subnet bits).
# Args:
#  - cidr: The CIDR value.
# Returns:
#  - subnetmask: A variable containing the subnet mask.

def subnet_mask(cidr):
  subnet = '0.0.0.0'
  cidr = int(cidr)
  if 0 < cidr <= 8:
    subnet_list = subnet.split('.')
    octet = subnet_list[0]
    subnet_list[0] = str(256 - 2 ** (8 - cidr))
    subnetmask = '.'.join(subnet_list)
    return subnetmask
  elif 9 <= cidr <= 16:
    subnet_list = subnet.split('.')
    subnet_list[0] = '255'
    octet = subnet_list[1]
    subnet_list[1] = str(256 - (2 ** (16 - cidr)))
    subnetmask = '.'.join(subnet_list)
    return subnetmask
  elif 17 <= cidr <= 24:
    subnet_list = subnet.split('.')
    subnet_list[0] = '255'
    subnet_list[1] = '255'
    octet = subnet_list[2]
    subnet_list[2] = str(256 - (2 ** (24 - cidr)))
    subnetmask = '.'.join(subnet_list)
    return subnetmask
  elif 25 <= cidr <= 32:
    subnet_list = subnet.split('.')
    subnet_list[0] = '255'
    subnet_list[1] = '255'
    subnet_list[2] = '255'
    octet = subnet_list[3]
    subnet_list[3] = str(256 - (2 ** (32 - cidr)))
    subnetmask = '.'.join(subnet_list)
    return subnetmask
  else:
    return "Something is wrong"

# %%
# Help function that calculates the number of hosts/subnets available based on the user choice.
# Args:
# - IP: The IP address to be checked.
# - user_partition_choice: must be a string containing subnets or hosts
# - initial_class_cidr: The Class CIDR value of the given IP.
# Returns:
#  - CIDR: A variable containing the final CIDR for the given IP with the user partition choice or None if there is an error.
def calculate_by_choice(ip, user_partition_choice, initial_class_cidr):
  if user_partition_choice == 'hosts':
      hosts_number = int(input("Enter the number of hosts you want in each network: "))
      i = 0
      while (2 ** i < hosts_number):
        i += 1
      cidr = 32 - i
    
  elif user_partition_choice == 'subnets':
    subnets_number = int(input("Enter the number of subnets you want in each network: "))
    # Calculate CIDR based on the number of subnets
    i = 0
    while 2 ** i < subnets_number:
      i += 1
    cidr = initial_class_cidr + i

  if cidr_validate(str(cidr), ip):
    print (f'this is the cidr {cidr}')
    return cidr
  else:
    return None

# Main function that calculates the number of hosts/subnets available based on the user choice.
# Args:
# - IP: The IP address to be checked.
# Returns:
#  - CIDR: A variable containing the final CIDR for the given IP with the user partition choice or None if there is an error.
def partition_by_user_choice(ip):
  initial_cidr = class_bit(ip)
  partition_choice = input("Enter your partitioning choice (type hosts or subnets): ")
  while partition_choice != 'hosts' and partition_choice != 'subnets':
      partition_choice = input("Invalid partitioning choice (type hosts or subnets): ")
  cidr = calculate_by_choice(ip, partition_choice, initial_cidr)
  if cidr == None:
        print("The number you asked for cannot be contained in the given Network")
        classbit = class_bit(ip)
        print(f"Initial Class CIDR is: {classbit}, giving you {32 - classbit} bits to play with")
        print(f"So in Simple Words, your maximum number for hosts/subnets: {2 ^ (32 - classbit) - 1}")
  return cidr

#This funtion gets the octet's value we need to change and the group size
#and returns the first range is bigger that octet that
def calculate_range(octet, size):
  for i in range(0, 256, size):
      if (int(octet) < i):
        return i
  return 0

#This funtion gets cidr as input
#and returns the number of the octet we need to change
def octet_number(cidr):
  if 25 <= cidr <= 32:
    return 3
  elif 17 <= cidr <= 24:
    return 2
  elif 9<= cidr <= 16:
    return 1
  elif 0 <= cidr <= 8:
    return 0
  return None

# %%
# function that calculates the Network address of the given network and the first/last two networks.
# Args:
# - IP: The IP address.
# - CIDR - the final CIDR by user
# Returns:
#  - Nothing(print function): print out each network address of the specified subnets.

def network_address(ip,cidr):
  cidr = int(cidr)
  # this variable calculates the group size
  size = 2 ** ((32 - cidr) % 8)
  ip_list = ip.split('.')
  ocNum = octet_number(cidr)
  if (ocNum == None):
    return "something is wrong"

  #This for makes all the next octet = 0
  for i in range(ocNum+1,4):
    ip_list[i] = str(0)

  #Here we need to print the networks

  #Here is the network address that the ip is part of
  octet = ip_list[ocNum]
  nearest_group_size = calculate_range(octet, size)
  ip_list[ocNum] = str(nearest_group_size - size)
  networkAdd = '.'.join(ip_list)
  print(f'The Network address: {networkAdd} ')

  #first network
  ip_list[ocNum] = str(0)
  networkAdd = '.'.join(ip_list)
  print(f'First Network address: {networkAdd} ')

  #second network
  ip_list[ocNum] = str(size)
  networkAdd = '.'.join(ip_list)
  print(f'Second Network address: {networkAdd} ')

  #last network
  ip_list[ocNum] = str(256 - size)
  networkAdd = '.'.join(ip_list)
  print(f'Last Network address: {networkAdd} ')

  #one before last
  ip_list[ocNum] = str(256 - 2 * size)
  networkAdd = '.'.join(ip_list)
  print(f'Second Last Network address: {networkAdd} ')

# %%
# function that calculates the Broadcast address of the given network and the first/last two networks.
# Args:
# - IP: The IP address.
# - CIDR - the final CIDR by user
# Returns:
#  - Nothing(print function): print out each Broadcast address of the specified subnets.

def broadcast_address(ip,cidr):
  cidr = int(cidr)
  # this variable calculates the group size
  size = 2 ** ((32 - cidr) % 8)
  ip_list = ip.split('.')
  ocNum = octet_number(cidr)
  if (ocNum == None):
    return "something is wrong"

  #This for makes all the next octet = 0
  for i in range(ocNum+1,4):
    ip_list[i] = str(255)

  #Here we need to print the broadcasts

  #Here is the network address that the ip is part of
  octet = ip_list[ocNum]
  nearest_group_size = calculate_range(octet, size)
  ip_list[ocNum] = str(nearest_group_size - 1)
  broadcastAdd = '.'.join(ip_list)
  print(f'The broadcast1 address: {broadcastAdd} ')

  #first network
  ip_list[ocNum] = str(size-1)
  broadcastAdd = '.'.join(ip_list)
  print(f'First broadcast address: {broadcastAdd} ')

  #second network
  ip_list[ocNum] = str(2*size-1)
  broadcastAdd = '.'.join(ip_list)
  print(f'Second broadcast address: {broadcastAdd} ')

  #last network
  ip_list[ocNum] = str(255)
  broadcastAdd = '.'.join(ip_list)
  print(f'Last broadcast address: {broadcastAdd} ')

  #one before last
  ip_list[ocNum] = str(255 - size)
  broadcastAdd = '.'.join(ip_list)
  print(f'Second Last broadcast address: {broadcastAdd} ')

# %%
# function that prints out all the info of a given IP and a given CIDR.
# Args:
# - IP: The IP address.
# - CIDR - the final CIDR by user
# Returns:
#  - Nothing(print function): print out all the information about a given IP.
def get_ip_info(ip,cidr):
  print(f'Class type: {determine_class(ip)}')
  print(f'Number of Avaliable Hosts: {get_hosts_number(ip, cidr)}')
  print(f'Number of Subnets: {get_subnets_number(ip, cidr)}')
  print(f'Subnet Mask: {subnet_mask(cidr)}')
  network_address(ip,cidr)
  broadcast_address(ip,cidr)
    
# Main function to execute the program.
# Purpose: This is the main function that runs when the program is executed
def main():
  ip = input("Enter an IP address (e.g., 192.168.1.1): ")
  while not ip_validate(ip):
    ip = input("Enter an VALID IP address (e.g., 192.168.1.1): ")
  print("Enter a CIDR block (e.g., 24)")
  cidr = input("if you don't want to add CIDR press ENTER: ")
  if cidr == '':
    cidr = partition_by_user_choice(ip)
  else:
    while (not cidr_validate(cidr,ip)):
      cidr = input("Enter a VALID CIDR block (e.g., 24): ")
      if cidr == '':
        cidr = partition_by_user_choice(ip)
  if cidr != None:
    get_ip_info(ip, cidr)
  else:
    print("requirments do not meet. Cidr must be more than the Class CIDR and less than 32")

# %%
main()
# Out:
# Enter an IP address (e.g., 192.168.1.1): 127.2.2.1
# Enter a CIDR block (e.g., 24)
# if you don't want to add CIDR press ENTER:
# Enter your partitioning choice (type hosts or subnets): 3000
# Invalid partitioning choice (type hosts or subnets): hosts
# Enter the number of hosts you want in each network: 3000
# this is the cidr 20
# Class type: Class A
# Number of Avaliable Hosts: 4094
# Number of Subnets: 4096
# Subnet Mask: 255.255.240.0
# The Network address: 127.2.0.0
# First Network address: 127.2.0.0
# Second Network address: 127.2.16.0
# Last Network address: 127.2.240.0
# Second Last Network address: 127.2.224.0
# The broadcast1 address: 127.2.15.255
# First broadcast address: 127.2.15.255
# Second broadcast address: 127.2.31.255
# Last broadcast address: 127.2.255.255
# Second Last broadcast address: 127.2.239.255
